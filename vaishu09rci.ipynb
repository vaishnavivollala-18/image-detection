# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="lCocpyMinKClHLZDdcge")
project = rf.workspace("vaishnavis-workspace-gdhj2").project("vaishnavi09")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.0/285.0 kB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 16.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 40.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 55.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 2.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 5.0.0.93
#     Uninstalling opencv-python-headless-5.0.0.93:
#       Successfully uninstalled opencv-python-headless-5.0.0.93
#   Attempting uninstall: typer
#     Found existing installation: typer 0.26.8
#     Uninstalling typer-0.26.8:
#       Successfully uninstalled typer-0.26.8
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to vaishnavi09-2 in yolov8:: 100%|██████████| 732/732 [00:00<00:00, 6663.03it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 136.3 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 9.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !ls /content
# Out:
# sample_data  vaishnavi09-2

# %%
# !ls /content/vaishnavi09-2
# Out:
# data.yaml  README.roboflow.txt	test  train  valid

# %%
# !cat /content/vaishnavi09-2/data.yaml
# Out:
# names:
# - vaishnavi09
# nc: 1
# roboflow:
#   license: Private
#   project: vaishnavi09
#   url: https://app.roboflow.com/vaishnavis-workspace-gdhj2/vaishnavi09/2
#   version: 2
#   workspace: vaishnavis-workspace-gdhj2
# test: ../test/images
# train: ../train/images
# val: ../valid/images

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/vaishnavi09-2/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# ...
# Ultralytics 8.4.112 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !find /content/runs/detect -name best.pt
# Out:
# /content/runs/detect/train/weights/best.pt

# %%
# !ls /content/runs/detect/train
# Out:
# args.yaml			 labels.jpg	     train_batch841.jpg
# BoxF1_curve.png			 results.csv	     train_batch842.jpg
# BoxP_curve.png			 results.png	     val_batch0_labels.jpg
# BoxPR_curve.png			 train_batch0.jpg    val_batch0_pred.jpg
# BoxR_curve.png			 train_batch1.jpg    weights
# confusion_matrix_normalized.png  train_batch2.jpg
# confusion_matrix.png		 train_batch840.jpg

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("/content/runs/detect/train/results.png")

plt.figure(figsize=(12,8))
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-414d9b6c-86b2-4ac7-8fc7-d1d189c94da4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-414d9b6c-86b2-4ac7-8fc7-d1d189c94da4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train/weights/best.pt")

# %%
results = model.predict(
    source="/content/0J2A3534.JPG",
    save=True,
    conf=0.25
)
# Out:
# image 1/1 /content/0J2A3534.JPG: 448x640 1 vaishnavi09, 6.2ms
# Speed: 3.5ms preprocess, 6.2ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict

# %%
# !find /content/runs/detect -path "*predict*" -type f
# Out:
# /content/runs/detect/predict/0J2A3534.jpg

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("/content/runs/detect/predict/0J2A3534.jpg")

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.axis("off")
plt.show()
